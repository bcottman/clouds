# %% [markdown]
# AWS/GCP/Azure — These providers expose the official cloud service assets that you would be using for any diagram that leverages one of the main cloud providers.

# %%
import matplotlib
# %matplotlib inline
import matplotlib.pyplot as plt

# %load_ext autoreload
# %autoreload 2
packages = !conda list
len(packages),packages
# Out:
# (201,
#  ['# packages in environment at /opt/conda:',
#   '#',
#   '# Name                    Version                   Build  Channel',
#   '_libgcc_mutex             0.1                 conda_forge    conda-forge',
#   '_openmp_mutex             4.5                       0_gnu    conda-forge',
#   'alembic                   1.4.2              pyh9f0ad1d_0    conda-forge',
#   'argon2-cffi               20.1.0                   pypi_0    pypi',
#   'async_generator           1.10                       py_0    conda-forge',
#   'attrs                     19.3.0                     py_0    conda-forge',
#   'backcall                  0.1.0                      py_0    conda-forge',
#   'bleach                    3.1.5              pyh9f0ad1d_0    conda-forge',
#   'blinker                   1.4                        py_1    conda-forge',
#   'blis                      0.4.1                    pypi_0    pypi',
#   'boto3                     1.16.4                   pypi_0    pypi',
#   'botocore                  1.19.4                   pypi_0    pypi',
#   'brotlipy                  0.7.0           py37h8f50634_1000    conda-forge',
#   'ca-certificates           2020.4.5.1           hecc5488_0    conda-forge',
#   'cachetools                4.1.1                    pypi_0    pypi',
#   'catalogue                 1.0.0                    pypi_0    pypi',
#   'certifi                   2020.6.20                pypi_0    pypi',
#   'certipy                   0.1.3                      py_0    conda-forge',
#   'cffi                      1.14.0           py37hd463f26_0    conda-forge',
#   'chardet                   3.0.4           py37hc8dfbb8_1006    conda-forge',
#   'click                     7.1.2                    pypi_0    pypi',
#   'cloudpickle               1.6.0                    pypi_0    pypi',
#   'cmake                     3.18.2.post1             pypi_0    pypi',
#   'conda                     4.8.2                    py37_0    conda-forge',
#   'conda-package-handling    1.6.0            py37h8f50634_2    conda-forge',
#   'configurable-http-proxy   4.2.1           node13_he01fd0c_0    conda-forge',
#   'cryptography              2.9.2            py37hb09aad4_0    conda-forge',
#   'cycler                    0.10.0                   pypi_0    pypi',
#   'cymem                     2.0.3                    pypi_0    pypi',
#   'cytoolz                   0.11.0                   pypi_0    pypi',
#   'dask                      2.30.0                   pypi_0    pypi',
#   'decorator                 4.4.2                      py_0    conda-forge',
#   'defusedxml                0.6.0                      py_0    conda-forge',
#   'diagrams                  0.17.0                   pypi_0    pypi',
#   'distributed               2.22.0                   pypi_0    pypi',
#   'dlib                      19.21.0                  pypi_0    pypi',
#   'emoji                     0.6.0                    pypi_0    pypi',
#   'en-core-web-lg            2.3.1                    pypi_0    pypi',
#   'en-core-web-sm            2.3.1                    pypi_0    pypi',
#   'entrypoints               0.3             py37hc8dfbb8_1001    conda-forge',
#   'filelock                  3.0.12                   pypi_0    pypi',
#   'ftfy                      5.8                      pypi_0    pypi',
#   'future                    0.18.2                   pypi_0    pypi',
#   'heapdict                  1.0.1                    pypi_0    pypi',
#   'icu                       64.2                 he1b5a44_1    conda-forge',
#   'idna                      2.10                     pypi_0    pypi',
#   'importlib-metadata        2.0.0                    pypi_0    pypi',
#   'importlib_metadata        1.6.0                         0    conda-forge',
#   'ipykernel                 5.3.0            py37h43977f1_0    conda-forge',
#   'ipython                   7.14.0           py37hc8dfbb8_0    conda-forge',
#   'ipython_genutils          0.2.0                      py_1    conda-forge',
#   'jedi                      0.17.0           py37hc8dfbb8_0    conda-forge',
#   'jellyfish                 0.8.2                    pypi_0    pypi',
#   'jinja2                    2.11.2             pyh9f0ad1d_0    conda-forge',
#   'jmespath                  0.10.0                   pypi_0    pypi',
#   'joblib                    0.17.0                   pypi_0    pypi',
#   'json5                     0.9.0                      py_0    conda-forge',
#   'jsonschema                3.2.0            py37hc8dfbb8_1    conda-forge',
#   'jupyter-contrib-core      0.3.3                    pypi_0    pypi',
#   'jupyter-contrib-nbextensions 0.5.1                    pypi_0    pypi',
#   'jupyter-highlight-selected-word 0.2.0                    pypi_0    pypi',
#   'jupyter-latex-envs        1.4.6                    pypi_0    pypi',
#   'jupyter-nbextensions-configurator 0.4.1                    pypi_0    pypi',
#   'jupyter_client            6.1.3                      py_0    conda-forge',
#   'jupyter_core              4.6.3            py37hc8dfbb8_1    conda-forge',
#   'jupyter_telemetry         0.0.5                      py_0    conda-forge',
#   'jupyterhub                1.1.0                    py37_2    conda-forge',
#   'jupyterhub-base           1.1.0                    py37_2    conda-forge',
#   'jupyterlab                2.1.3                      py_0    conda-forge',
#   'jupyterlab_server         1.1.5                      py_0    conda-forge',
#   'jupyterthemes             0.20.0                   pypi_0    pypi',
#   'kiwisolver                1.2.0                    pypi_0    pypi',
#   'krb5                      1.17.1               h2fd8d38_0    conda-forge',
#   'ld_impl_linux-64          2.34                 h53a641e_0    conda-forge',
#   'lesscpy                   0.14.0                   pypi_0    pypi',
#   'libcurl                   7.69.1               hf7181ac_0    conda-forge',
#   'libedit                   3.1.20170329      hf8c457e_1001    conda-forge',
#   'libffi                    3.2.1             he1b5a44_1007    conda-forge',
#   'libgcc-ng                 9.2.0                h24d8f2e_2    conda-forge',
#   'libgomp                   9.2.0                h24d8f2e_2    conda-forge',
#   'libsodium                 1.0.17               h516909a_0    conda-forge',
#   'libssh2                   1.9.0                hab1572f_2    conda-forge',
#   'libstdcxx-ng              9.2.0                hdf63c60_2    conda-forge',
#   'libuv                     1.34.0               h516909a_0    conda-forge',
#   'llvmlite                  0.34.0                   pypi_0    pypi',
#   'lxml                      4.6.1                    pypi_0    pypi',
#   'mako                      1.1.0                      py_0    conda-forge',
#   'markupsafe                1.1.1            py37h8f50634_1    conda-forge',
#   'matplotlib                3.3.1                    pypi_0    pypi',
#   'mistune                   0.8.4           py37h8f50634_1001    conda-forge',
#   'msgpack                   1.0.0                    pypi_0    pypi',
#   'murmurhash                1.0.2                    pypi_0    pypi',
#   'nbconvert                 5.6.1            py37hc8dfbb8_1    conda-forge',
#   'nbformat                  5.0.6                      py_0    conda-forge',
#   'ncurses                   6.1               hf484d3e_1002    conda-forge',
#   'networkx                  2.5                      pypi_0    pypi',
#   'nibabel                   3.2.0                    pypi_0    pypi',
#   'nilearn                   0.5.0                    pypi_0    pypi',
#   'nltk                      3.5                      pypi_0    pypi',
#   'nodejs                    13.13.0              hf5d1a2b_0    conda-forge',
#   'notebook                  6.1.4                    pypi_0    pypi',
#   'numba                     0.51.0                   pypi_0    pypi',
#   'numpy                     1.19.1                   pypi_0    pypi',
#   'oauthlib                  3.0.1                      py_0    conda-forge',
#   'openssl                   1.1.1g               h516909a_0    conda-forge',
#   'packaging                 20.4               pyh9f0ad1d_0    conda-forge',
#   'pamela                    1.0.0                      py_0    conda-forge',
#   'pandas                    1.1.3                    pypi_0    pypi',
#   'pandoc                    2.9.2.1                       0    conda-forge',
#   'pandocfilters             1.4.2                      py_1    conda-forge',
#   'parso                     0.7.0              pyh9f0ad1d_0    conda-forge',
#   'pdfminer                  20191125                 pypi_0    pypi',
#   'pexpect                   4.8.0            py37hc8dfbb8_1    conda-forge',
#   'pickleshare               0.7.5           py37hc8dfbb8_1001    conda-forge',
#   'pillow                    8.0.1                    pypi_0    pypi',
#   'pip                       20.1.1                   pypi_0    pypi',
#   'plac                      1.1.3                    pypi_0    pypi',
#   'ply                       3.11                     pypi_0    pypi',
#   'preshed                   3.0.2                    pypi_0    pypi',
#   'prometheus_client         0.8.0              pyh9f0ad1d_0    conda-forge',
#   'prompt-toolkit            3.0.5                      py_0    conda-forge',
#   'psutil                    5.7.3                    pypi_0    pypi',
#   'ptyprocess                0.6.0                   py_1001    conda-forge',
#   'pycosat                   0.6.3           py37h8f50634_1004    conda-forge',
#   'pycparser                 2.20                       py_0    conda-forge',
#   'pycryptodome              3.9.8                    pypi_0    pypi',
#   'pycurl                    7.43.0.5         py37h16ce93b_0    conda-forge',
#   'pyemd                     0.5.1                    pypi_0    pypi',
#   'pygments                  2.6.1                      py_0    conda-forge',
#   'pyjwt                     1.7.1                      py_0    conda-forge',
#   'pyopenssl                 19.1.0                     py_1    conda-forge',
#   'pyparsing                 2.4.7              pyh9f0ad1d_0    conda-forge',
#   'pyphen                    0.9.5                    pypi_0    pypi',
#   'pyrsistent                0.16.0           py37h8f50634_0    conda-forge',
#   'pysocks                   1.7.1            py37hc8dfbb8_1    conda-forge',
#   'python                    3.7.6           h8356626_5_cpython    conda-forge',
#   'python-dateutil           2.8.1                      py_0    conda-forge',
#   'python-editor             1.0.4                      py_0    conda-forge',
#   'python-graphviz           0.13.2                   pypi_0    pypi',
#   'python-json-logger        0.1.11                     py_0    conda-forge',
#   'python_abi                3.7                     1_cp37m    conda-forge',
#   'pytokenizations           0.6.0                    pypi_0    pypi',
#   'pytz                      2020.1                   pypi_0    pypi',
#   'pyyaml                    5.3.1                    pypi_0    pypi',
#   'pyzmq                     19.0.1           py37hac76be4_0    conda-forge',
#   'readline                  8.0                  hf8c457e_0    conda-forge',
#   'regex                     2020.10.23               pypi_0    pypi',
#   'requests                  2.24.0                   pypi_0    pypi',
#   'ruamel.yaml               0.16.6           py37h8f50634_1    conda-forge',
#   'ruamel.yaml.clib          0.2.0            py37h8f50634_1    conda-forge',
#   'ruamel_yaml               0.15.80         py37h8f50634_1001    conda-forge',
#   's3transfer                0.3.3                    pypi_0    pypi',
#   'sacremoses                0.0.43                   pypi_0    pypi',
#   'scikit-learn              0.23.2                   pypi_0    pypi',
#   'scipy                     1.5.3                    pypi_0    pypi',
#   'seaborn                   0.11.0                   pypi_0    pypi',
#   'send2trash                1.5.0                      py_0    conda-forge',
#   'sentencepiece             0.1.94                   pypi_0    pypi',
#   'setuptools                50.3.2                   pypi_0    pypi',
#   'six                       1.15.0                   pypi_0    pypi',
#   'sortedcontainers          2.2.2                    pypi_0    pypi',
#   'spacy                     2.3.2                    pypi_0    pypi',
#   'spacy-symspell            0.1.2                    pypi_0    pypi',
#   'spacy-transformers        0.6.2                    pypi_0    pypi',
#   'spacymoji                 2.0.0                    pypi_0    pypi',
#   'sqlalchemy                1.3.17           py37h8f50634_0    conda-forge',
#   'sqlite                    3.30.1               hcee41ef_0    conda-forge',
#   'srsly                     1.0.2                    pypi_0    pypi',
#   'symspellcpppy             0.0.8                    pypi_0    pypi',
#   'symspellpy                6.7.0                    pypi_0    pypi',
#   'tblib                     1.7.0                    pypi_0    pypi',
#   'terminado                 0.8.3            py37hc8dfbb8_1    conda-forge',
#   'testpath                  0.4.4                      py_0    conda-forge',
#   'textacy                   0.10.1                   pypi_0    pypi',
#   'thinc                     7.4.1                    pypi_0    pypi',
#   'threadpoolctl             2.1.0                    pypi_0    pypi',
#   'tini                      0.18.0            h14c3975_1001    conda-forge',
#   'tk                        8.6.10               hed695b0_0    conda-forge',
#   'tokenizers                0.5.2                    pypi_0    pypi',
#   'toolz                     0.11.1                   pypi_0    pypi',
#   'torch                     1.6.0                    pypi_0    pypi',
#   'torchcontrib              0.0.2                    pypi_0    pypi',
#   'tornado                   6.0.4            py37h8f50634_1    conda-forge',
#   'tqdm                      4.50.2                   pypi_0    pypi',
#   'traitlets                 4.3.3            py37hc8dfbb8_1    conda-forge',
#   'transformers              2.8.0                    pypi_0    pypi',
#   'urllib3                   1.25.10                  pypi_0    pypi',
#   'wasabi                    0.8.0                    pypi_0    pypi',
#   'wcwidth                   0.2.5                    pypi_0    pypi',
#   'webencodings              0.5.1                      py_1    conda-forge',
#   'wheel                     0.34.2                     py_1    conda-forge',
#   'wordsegment               1.3.1                    pypi_0    pypi',
#   'xz                        5.2.5                h516909a_0    conda-forge',
#   'yaml                      0.2.4                h516909a_0    conda-forge',
#   'zeromq                    4.3.2                he1b5a44_2    conda-forge',
#   'zict                      2.0.0                    pypi_0    pypi',
#   'zipp                      3.3.2                    pypi_0    pypi',
#   'zlib                      1.2.11            h516909a_1006    conda-forge'])

# %%
from graphviz import Digraph

dot = Digraph(comment='The Round Table')

print(dot)
dot.node('A', 'King Arthur')
dot.node('B', 'Sir Bedevere the Wise')
dot.node('L', 'Sir Lancelot the Brave')

dot.edges(['AB', 'AL'])
dot.edge('B', 'L', constraint='false')
print(dot.source) 
dot.render('test-output/round-table.jpg', view=True)
dot
# Out:
# // The Round Table
# digraph {
# }
# // The Round Table
# digraph {
# 	A [label="King Arthur"]
# 	B [label="Sir Bedevere the Wise"]
# 	L [label="Sir Lancelot the Brave"]
# 	A -> B
# 	A -> L
# 	B -> L [constraint=false]
# }

# %% [markdown]
# ## IAM

# %%
from diagrams import Diagram , Edge
from diagrams.aws.security import IdentityAndAccessManagementIam as IAM
from diagrams.gcp.security import Iam
from diagrams.azure.identity import ActiveDirectory as ADS

with Diagram("\n Identity  and Access Management", direction='LR') as diag:
    c = Edge(color="white", style="dashed")


    aec=IAM("AWS IAM")
    azcr = ADS("Azure Active Directory ")
    gcp= Iam("GCP IAM")
    aec  -  c - azcr -  c - gcp
    
    
diag
# Out:
# Warning: node 'fed7193207e04485b993cffb98a30ba7', graph '
#  Identity  and Access Management' size too small for label

# %% [markdown]
# ## cloud compute engine

# %%
from diagrams import Diagram , Edge
from diagrams.aws.compute import EC2
from diagrams.gcp.compute import ComputeEngine
from diagrams.azure.compute import CloudsimpleVirtualMachines

with Diagram("\n Compute Engine", direction='LR') as diag:
    c = Edge(color="white", style="dashed")


    aec=EC2("AWS ")
    azcr = CloudsimpleVirtualMachines("CSVM ")
    gcp= ComputeEngine("GCP GCE")
    aec  -  c - azcr -  c - gcp
    
    
diag

# %% [markdown]
# ## Severless Compute Engine

# %%
from diagrams.aws.compute import Lambda
from diagrams.gcp.compute import AppEngine
from diagrams.azure.compute import FunctionApps

with Diagram("\n Serverless Compute Engine", direction='LR') as diag:
    c = Edge(color="white", style="dashed")


    aec=Lambda("AWS Lambda")
    azcr = FunctionApps("Azure FunctionApps ")
    gcp= AppEngine("GCP GCE")
    aec  -  c - azcr -  c - gcp
    
diag
# Out:
# Warning: node '56429eb623154f49850b811b572f81a8', graph '
#  Serverless Compute Engine' size too small for label

# %% [markdown]
# ### kebernetes

# %%
from diagrams.aws.compute import ElasticKubernetesService as EKS
from diagrams.azure.compute import KubernetesServices as KS
from diagrams.gcp.compute import KubernetesEngine as KE
with Diagram("\n Kubernetes ", direction='LR') as diag:
    c = Edge(color="white", style="dashed")

    aws= EKS("AWS Elastic Kubernetes")
    az= KS("Azure Kubernetes" )
    gcp = KE("GCP Kubernetes")
    aws -  c - az- c - gcp
diag
# Out:
# Warning: node '97e4fc4b16e944379aa61145f96e0302', graph '
#  Kubernetes ' size too small for label
# Warning: node '897024ab568f4c0183b26bd1bdb5aead', graph '
#  Kubernetes ' size too small for label

# %% [markdown]
# ## Storage

# %%
from diagrams.aws.storage import SimpleStorageServiceS3
from diagrams.azure.storage import GeneralStorage
from diagrams.gcp.storage import GCS

# %%
with Diagram("\n Storage", direction='LR') as diag:
    c = Edge(color="white", style="dashed")

    s3 = SimpleStorageServiceS3("AWS S3")
    abst = GeneralStorage("Azure GeneralStorage" )
    gcs = GCS("GCP Cloud Storage")
    s3 -  c - abst - c - gcs
diag
# Out:
# Warning: node 'dc786f0342ab4a48b0053d82f11c5675', graph '
#  Storage' size too small for label
# Warning: node '68cfaeead0b640698b022cace423b034', graph '
#  Storage' size too small for label

# %% [markdown]
# ## Big Data

# %%
from diagrams.onprem.database import Hbase
from diagrams.gcp.database import Bigtable


with Diagram("\n Big Data Storage", direction='LR') as diag:
    c = Edge(color="white", style="dashed")

    s3 = Hbase("AWS Apache Hbase")
    abst = Hbase("Azure Apache Hbase" )
    gcs = Bigtable("GCP Bigtable")
    s3 -  c - abst - c - gcs
diag
# Out:
# Warning: node 'c78da7472032415294e687f7d2769874', graph '
#  Big Data Storage' size too small for label
# Warning: node '5110867b73b849f9a67fed81bb07954b', graph '
#  Big Data Storage' size too small for label

# %% [markdown]
# ## OLTP

# %%
from diagrams.aws.analytics import Athena
from diagrams.azure.analytics import Databricks
#diagrams.azure.analytics.AnalysisServices
from diagrams.gcp.analytics import Bigquery


with Diagram("\n OLTP", direction='LR') as diag:
    c = Edge(color="white", style="dashed")

    s3 = Athena("AWS Athena")
    abst = Databricks("Azure Apache Databricks" )
    gcs = Bigquery("GCP Bigquery")
    s3 -  c - abst - c - gcs
diag
# Out:
# Warning: node 'd548446b3f534064b8b01f185e9c28df', graph '
#  OLTP' size too small for label

# %% [markdown]
# ## SQL

# %%
from diagrams.aws.database import Aurora
from diagrams.azure.database import SQLDatabases
from diagrams.gcp.database import SQL
with Diagram("\n SQL RDMS", direction='LR') as diag:
    c = Edge(color="white", style="dashed")

    s3 = Aurora("AWS Aurora")
    abst = SQLDatabases("Azure SQLDatabases" )
    gcs = SQL("GCP SQL")
    s3 -  c - abst - c - gcs
diag
# Out:
# Warning: node '4c13628024a7409f9a2fb8cf74439a37', graph '
#  SQL RDMS' size too small for label

# %%
## Monitoring

# %%
from diagrams.aws.devtools import XRay

# %% [markdown]
# ## VPC

# %%
from diagrams.aws.network import VPC as aVPC
from diagrams.azure.network import VirtualNetworkClassic
from  diagrams.gcp.network import VPC

# %%
with Diagram("\n Virtual Private Network", direction='LR') as diag:
    c = Edge(color="white", style="dashed")

    awsnet = aVPC("AWS VPV")
    aznet= VirtualNetworkClassic("Azure VPC" )
    gcpnet = VPC("GCP VPC")
    awsnet -  c - aznet - c - gcpnet
diag

# %% [markdown]
# ### Machine Learning

# %%
from diagrams.aws.ml import Sagemaker
from diagrams.azure.ml import CognitiveServices
from diagrams.gcp.ml import Automl

# %%
with Diagram("\n General Machine Learning ", direction='LR') as diag:
    c = Edge(color="white", style="dashed")

    awsml = Sagemaker("AWS Sagemaker")
    azml= CognitiveServices("Azure CognitiveServices" )
    gcpml = Automl("GCP AutoML")
    awsml -  c - azml - c - gcpml
diag
# Out:
# Warning: node '072d373d724e4e3e84c224a081f972d8', graph '
#  General Machine Learning ' size too small for label

# %% [markdown]
# ## natural language

# %%
from diagrams.aws.ml import Translate
#from 
from diagrams.gcp.ml import AutomlTranslation

# %%
with Diagram("\n Natural Language Translation", direction='LR') as diag:
    c = Edge(color="white", style="dashed")

    awsml = Translate("AWS Translation")
#    azml=diagrams.azure.ml.CognitiveServices("Azure CognitiveServices" )
    gcpml = AutomlTranslation("GCP Translation")
#    awsml -  c - azml - c - gcpml
    awsml - c - gcpml
diag
# Out:
# Warning: node 'd36358e6bd86418c81cea0a4a1515024', graph '
#  Natural Language Translation' size too small for label
# Warning: node '4d2dace5d80b4b34b462fc3219a2eeef', graph '
#  Natural Language Translation' size too small for label

# %%
from diagrams.aws.ml import Personalize
from diagrams.gcp.ml import RecommendationsAI

# %%
with Diagram("\n Recommendation", direction='LR') as diag:
    c = Edge(color="white", style="dashed")

    awsml = Personalize("AWS Recommendation")
#    azml=diagrams.azure.ml.CognitiveServices("Azure CognitiveServices" )
    gcpml = RecommendationsAI("GCP Recommendation")
#    awsml -  c - azml - c - gcpml
    awsml - c - gcpml
diag
# Out:
# Warning: node 'c29b942d51b947a5817e1cc4eb7d5576', graph '
#  Recommendation' size too small for label
# Warning: node '4f5d30abae8d49f783be4caacfdcbdc0', graph '
#  Recommendation' size too small for label

# %% [markdown]
# ## LoadBalancing

# %%
from diagrams.aws.network import ElasticLoadBalancing
from diagrams.azure.network import LoadBalancers as LoadBalancers
from diagrams.gcp.network import LoadBalancing

# %%
with Diagram("\n LoadBalancers ", direction='LR') as diag:
    c = Edge(color="white", style="dashed")

    awslb= ElasticLoadBalancing("AWS ELB")
    azlb= LoadBalancers("Azure LoadBalancer" )
    gcplb= LoadBalancing("GCP LoadBalancing")
    awslb-  c - azlb- c - gcplb
diag
# Out:
# Warning: node '6dfaf8592a43462a841f04b86f54f117', graph '
#  LoadBalancers ' size too small for label
# Warning: node '013703f2514d4524849c1f8632cbb3b3', graph '
#  LoadBalancers ' size too small for label

# %% [markdown]
# ## NAT

# %%
from diagrams.aws.network import NATGateway
from  diagrams.azure.network import LocalNetworkGateways
from diagrams.gcp.network import NAT
with Diagram("\n NAT ", direction='LR') as diag:
#    c = Edge(color="firebrick", style="dashed")
    c = Edge(color="white", style="dashed")

    awsNAT = NATGateway("AWS NAT")
    azNAT = LocalNetworkGateways("Azure NetworkGateway" )
    gcpNAT= NAT("GCP NAT")
    awsNAT-  c - azNAT- c - gcpNAT
diag
# Out:
# Warning: node '3dc85a6b56444417bc8294ee1155bb8d', graph '
#  NAT ' size too small for label

# %%
with Diagram("\n DNS ", direction='LR') as diag:
    c = Edge(color="white", style="dashed")

    awsDNS= diagrams.aws.network.DirectConnect("AWS NAT")
    azDNS = diagrams.azure.network.DNSZones("Azure NetworkGateway" )
    gcpDNS= diagrams.gcp.network.NAT("GCP NAT")
    awsDNS-  c - azDNS- c - gcpDNS
diag
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-25-4b24f99bc966> in <module>
#       2     c = Edge(color="white", style="dashed")
#       3
# ----> 4     awsDNS= diagrams.aws.network.DirectConnect("AWS NAT")
#       5     azDNS = diagrams.azure.network.DNSZones("Azure NetworkGateway" )
#       6     gcpDNS= diagrams.gcp.network.NAT("GCP NAT")
#
# NameError: name 'diagrams' is not defined

# %%
with Diagram("\n GCP Machine Learning and Deep Learning Services ", direction='LR') as diag:
#    c = Edge(color="firebrick", style="dashed")
    c = Edge(color="white", style="dashed")

    gcp_11 = diagrams.gcp.ml.AdvancedSolutionsLab("AdvancedSolutionsLab")
    gcp_21 = diagrams.gcp.ml.AIHub("AIHub" )
    gcp_31 =diagrams.gcp.ml.AIPlatformDataLabelingService("DataLabeling")
    gcp_41 = diagrams.gcp.ml.AIPlatform("AIPlatform")
    gcp_51 = diagrams.gcp.ml.InferenceAPI("InferenceAPI")
    gcp_61 = diagrams.gcp.ml.JobsAPI("JobsAPI") 
    gcp_11 -  c - gcp_21 - c - gcp_31 - c - gcp_41 - c - gcp_51 - c - gcp_61
    #
    gcp_12 = diagrams.gcp.ml.AutomlNaturalLanguage("AutomlNaturalLanguage")
    gcp_22 = diagrams.gcp.ml.AutomlTranslation("AutomlTranslation" )
    gcp_32 =diagrams.gcp.ml.SpeechToText("SpeechToText")
    gcp_42 = diagrams.gcp.ml.TextToSpeech("TextToSpeech")
    gcp_52 = diagrams.gcp.ml.TranslationAPI("TranslationAPI")
    gcp_62 = diagrams.gcp.ml.NaturalLanguageAPI("NaturalLanguageAPI")    
    gcp_12 -  c - gcp_22 - c - gcp_32 - c - gcp_42 - c - gcp_52 - c - gcp_62
 #   
    gcp_13 = diagrams.gcp.ml.DialogFlowEnterpriseEdition("DialogFlowEnterprise")
    gcp_23 = diagrams.gcp.ml.TPU("TPU" )
    gcp_33 =diagrams.gcp.ml.AutomlVideoIntelligence("AutomlVideoIntelligence")
    gcp_43 = diagrams.gcp.ml.VideoIntelligenceAPI("VideoIntelligenceAPI")
    gcp_53 = diagrams.gcp.ml.VisionAPI("VisionAPI")    
    gcp_13 -  c - gcp_23 - c - gcp_33 - c - gcp_43 - c - gcp_53

diag

# %% [markdown]
# ## Excercise 3-8 Architecture

# %%
from diagrams import Diagram, Cluster
from diagrams.aws.compute import EC2
from diagrams.aws.network import ELB
from diagrams.aws.network import Route53
from diagrams.onprem.database import PostgreSQL # Would typically use RDS from aws.database
from diagrams.onprem.inmemory import Redis # Would typically use ElastiCache from aws.database
from diagrams.aws.ml import Rekognition

with Diagram("Week-3-8 Exercise", direction='LR') as diag: # It's LR by default, but you have a few options with the orientation
    dns = Route53("dns")
    load_balancer = ELB("Elastic Load Balancer")
    database = PostgreSQL("RDS mySQL")
#    cache = Redis("Cache")
    with Cluster("Webserver Cluster"):
        svc_group = [EC2("EC2 Webserver 1"),
                    EC2("EC2 Webserver 2")]
    dns >> load_balancer >> svc_group
#    svc_group >> cache
    svc_group >> database
diag # This will illustrate the diagram if you are using a Google Colab or Jypiter notebook.

# %% [markdown]
# ## big AWS architecture

# %%
from diagrams import Diagram, Cluster
from diagrams.aws.compute import EC2
from diagrams.aws.network import ELB
from diagrams.aws.network import Route53
from diagrams.onprem.database import Mysql 
from diagrams.aws.compute import Lambda
from diagrams.aws.storage import SimpleStorageServiceS3
from diagrams.aws.network import VPCRouter
from diagrams.aws.ml import Rekognition

with Diagram("Azure Archecture", direction='LR') as diag: 
    dns = Route53("dns")
    vpc = VPCRouter("VPC")
    load_balancer = ELB("Elastic Load Balancer")
    database = Mysql("RDS mySQL")
    lambda1 = Lambda("microservice 1")
    lambda2 = Lambda("microservice 2")
    rek = Rekognition("Rekognition")
    s3 = SimpleStorageServiceS3("S3")
    with Cluster("Webserver Cluster"):
        svc_group = [EC2("EC2 Webserver 1"),
                    EC2("EC2 Webserver 2")]
    dns >> load_balancer >> vpc
    vpc >> svc_group >> database
    vpc >> svc_group >> lambda1
    lambda1 >> s3
    vpc >> svc_group >> lambda2
    lambda2 >> s3
    vpc >> svc_group >> rek
    rek >> s3
diag

# %%
from diagrams import Diagram, Cluster
from diagrams.azure.network import Connections
from diagrams.onprem.database import Mssql
from diagrams.azure.compute import ContainerInstances
from diagrams.azure.ml import CognitiveServices
from diagrams.azure.analytics import Databricks
from diagrams.azure.storage import TableStorage
from diagrams.azure.web import AppServices

with Diagram("Azure Archecture", direction='LR') as diag: 
    dns = Connections("http")
    vpc = Databricks("Databricks")
    database = Mssql("Mssql")
    lambda1 = ContainerInstances("microservice 1")
    lambda2 = ContainerInstances("microservice 2")
    ml = CognitiveServices("CognitiveServices")
    storage = TableStorage("TableStorage")
    with Cluster("Webserver Cluster"):
        svc_group = [AppServices("Appserver 1"),
                    AppServices("Appserver 2")]
    dns  >> vpc
    vpc >> svc_group >> database
    vpc >> svc_group >> lambda1
    lambda1 >> storage
    vpc >> svc_group >> lambda2
    lambda2 >> storage
    vpc >> svc_group >> ml
    ml >> storage
diag

# %% [markdown]
# ## GCP

# %%
from diagrams import Diagram, Cluster
from diagrams.onprem.database import Oracle
from diagrams.gcp.network import DedicatedInterconnect
from diagrams.gcp.network import LoadBalancing
from diagrams.gcp.compute import ContainerOptimizedOS
from diagrams.gcp.ml import AutomlVision
from diagrams.gcp.network import VirtualPrivateCloud
from diagrams.gcp.storage import Storage
from diagrams.gcp.compute import KubernetesEngine

with Diagram("GCP Archecture", direction='LR') as diag: 
    dns = DedicatedInterconnect("http")
    load_balancer = LoadBalancing("Load Balancer")
    vpc = VirtualPrivateCloud("VPC")
    database = Oracle("Oracle")
    lambda1 = ContainerOptimizedOS("microservice 1")
    lambda2 = ContainerOptimizedOS("microservice 2")
    ml = AutomlVision("AutomlVision")
    storage = Storage("Storage")
    with Cluster("Kubernetes Cluster"):
        svc_group = [KubernetesEngine("KubernetesEngine 1"),
                    KubernetesEngine("KubernetesEngine 2")]
    dns >> load_balancer >> vpc
    vpc >> svc_group >> database
    vpc >> svc_group >> lambda1
    lambda1 >> storage
    vpc >> svc_group >> lambda2
    lambda2 >> storage
    vpc >> svc_group >> ml
    ml >> storage
diag
